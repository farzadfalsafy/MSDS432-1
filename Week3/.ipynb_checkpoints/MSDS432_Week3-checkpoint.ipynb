# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import time
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def fact(x):
  if x == 1:
    return 1
  else:
    return x * fact(x-1)

# %% [markdown]
# ## Create Array and Write FOR Loop to Get Factorials

# %%
# Set seed for replicability and 
np.random.seed(14)
array = list(np.random.randint(low=100, high=500, size=10))
array
# Out:
# [207, 444, 368, 427, 349, 458, 334, 256, 238, 308]

# %%
# Use a FOR loop to get factorials
for_loop_executiontimes = []
for_factorials = []
for i in array:
    number = i
    factorial = 1
    t1 = time.perf_counter()
    for k in range(1, number+1):
        factorial = factorial*k
        for_factorials.append(factorial)
    t2 = time.perf_counter()
    execution = t2-t1
    for_loop_executiontimes.append(execution)
    print(f'Factorial of {i} is {factorial}')
# Out:
# Factorial of 207 is 
# Factorial of 444 is ...
# Factorial of 368 is ...
# Factorial of 427 is ...
# Factorial of 349 is ...
# Factorial of 458 is ...
# Factorial of 334 is ...
# Factorial of 256 is ...
# Factorial of 238 is ...
# Factorial of 308 is ...

# %%
# Use recursion to get factorials -- code taken from https://github.com/egonSchiele/grokking_algorithms/blob/master/03_recursion/python/03_factorial.py

recursion_executiontimes = []
recursion_factorials = []

for i in [207, 444, 368, 427, 349, 458, 334, 256, 238, 308]:
    t1 = time.perf_counter()
    factorial = fact(i)
    t2 = time.perf_counter()
    execution = t2-t1
    recursion_executiontimes.append(execution)
    recursion_factorials.append(factorial)

# %%
recursion_times = []
recursion_factorials = []
for i in [207, 444, 368, 427, 349, 458, 334, 256, 238, 308]:
    t1 = time.perf_counter()
    factorial = fact(i)
    t2 = time.perf_counter()
    execution = t2-t1
    recursion_factorials.append(factorial)
    recursion_times.append(execution)
    print(execution)
# Out:
# 0.0003015000002051238
# 0.00031820000003790483
# 0.00025160000041068997
# 0.0002885000003516325
# 0.00024649999977555126
# 0.0003082000002905261
# 0.00023070000042935135
# 0.00027380000028642826
# 0.00017740000021149172
# 0.00021090000063850312
# C:\Users\TJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in long_scalars
#   """

# %%
recursion_factorials
# Out:
# [,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...]
